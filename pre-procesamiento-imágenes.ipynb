# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from scipy.signal import convolve2d as conv
# %matplotlib inline

# %%
img = cv.imread('3.jpeg')
img_gris = cv.cvtColor(img, cv.COLOR_BGRA2GRAY)
cv.imshow ('Original', img)
cv.imshow ('Escala_grises', img_gris)
k = cv.waitKey(0)
if k == ord("s"):
    cv.imwrite("3.png", imag)
cv.destroyAllWindows ()

# %%
def captura(imgPath):
    img = cv.imread(imgPath)
    img_gris = cv.cvtColor(img, cv.COLOR_BGRA2GRAY)
    #img_gris_doube = np.zeros_like(img_gris)
    img_gris_double = img_gris / np.max(img_gris)    
    fig, ax = plt.subplots()
    fig.set_size_inches((15,10))
    ax.imshow(img_gris,cmap = 'gray') 
    ax.axis('off')
    plt.show()
    return [img, img_gris, img_gris_double]

def mostrar(img):
    fig, ax = plt.subplots()
    fig.set_size_inches((15,10))
    ax.imshow(img,cmap = 'gray') 
    ax.axis('off')
    plt.show()

# %%
imgPath = '3.jpeg'
captura(imgPath)
# Out:
# [array([[[204, 200, 195],
#          [204, 200, 195],
#          [204, 199, 196],
#          ...,
#          [166, 162, 173],
#          [166, 165, 175],
#          [167, 166, 176]],
#
#         [[188, 184, 179],
#          [188, 184, 179],
#          [188, 183, 180],
#          ...,
#          [168, 164, 175],
#          [170, 166, 177],
#          [169, 168, 178]],
#
#         [[197, 192, 189],
#          [197, 192, 189],
#          [197, 192, 189],
#          ...,
#          [173, 168, 177],
#          [174, 169, 178],
#          [173, 170, 179]],
#
#         ...,
#
#         [[ 72,  67,  68],
#          [ 74,  69,  70],
#          [ 74,  69,  70],
#          ...,
#          [154, 136, 183],
#          [154, 132, 184],
#          [151, 132, 183]],
#
#         [[104,  99, 100],
#          [107, 102, 103],
#          [109, 104, 105],
#          ...,
#          [156, 140, 188],
#          [155, 136, 187],
#          [151, 133, 186]],
#
#         [[ 83,  78,  79],
# ...

# %%
# Kernel Laplaciano (realzar bordes)
h = np.asarray([[0, 1, 0], [1, -16, 1], [0, 1, 0]])
h1 = (1/9)*np.ones((3,3))
img_filtrada = conv(x[1], h1)
img_filtrada = np.uint8(255 * img_filtrada / np.max(img_filtrada))

# %%
mostrar(img_filtrada)

# %%
x = ones
# Out:
# 255
